# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('C:\\Users\\Armaan\\OneDrive\\Pictures\\Picture1.png')
gray=cv2.imread('C:\\Users\\Armaan\\OneDrive\\Pictures\\Picture1.png',cv2.IMREAD_GRAYSCALE)
new_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(new_img)
plt.show()

# %%
cv2.imshow("Grey",gray)
cv2.imshow('CAR',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
