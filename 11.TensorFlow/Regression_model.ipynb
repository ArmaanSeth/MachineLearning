# %%
# importing dependencies
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

# %%
dataset=make_regression(n_samples=50,n_features=1,random_state=5,noise=20)
x=dataset[0]
y=dataset[1]
type(x)
# Out:
# numpy.ndarray

# %%
plt.scatter(x,y)
plt.show()

# %%
# x=np.array([-7.,-4.,-1.,2.,5.,8.,11.,14.])
# y=np.array([3.,6.,9.,12.,15.,18.,21.,24.])
# x=np.array([-7,-4,-1,2,5,8,11,14])
# y=np.array([3,6,9,12,15,18,21,24])
# x=tf.cast(tf.constant(x),dtype=tf.float16)
# y=tf.cast(tf.constant(y),dtype=tf.float16)
type(x[0])
# Out:
# numpy.ndarray

# %%
tf.random.set_seed(42)
model1=tf.keras.Sequential()
model1.add(tf.keras.layers.Dense(1))
model1.compile(loss=tf.keras.losses.mae,optimizer=tf.keras.optimizers.Adam(),metrics=["mae"])
model1.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 2s 8ms/step - loss: 34.8193 - mae: 34.8193
# Epoch 2/10
# 2/2 [==============================] - 0s 9ms/step - loss: 34.8180 - mae: 34.8180
# Epoch 3/10
# 2/2 [==============================] - 0s 0s/step - loss: 34.8170 - mae: 34.8170
# Epoch 4/10
# 2/2 [==============================] - 0s 0s/step - loss: 34.8158 - mae: 34.8158
# Epoch 5/10
# 2/2 [==============================] - 0s 0s/step - loss: 34.8147 - mae: 34.8147
# Epoch 6/10
# 2/2 [==============================] - 0s 8ms/step - loss: 34.8135 - mae: 34.8135
# Epoch 7/10
# 2/2 [==============================] - 0s 0s/step - loss: 34.8124 - mae: 34.8124
# Epoch 8/10
# 2/2 [==============================] - 0s 8ms/step - loss: 34.8112 - mae: 34.8112
# Epoch 9/10
# 2/2 [==============================] - 0s 8ms/step - loss: 34.8102 - mae: 34.8102
# Epoch 10/10
# 2/2 [==============================] - 0s 8ms/step - loss: 34.8091 - mae: 34.8091

# %%
tf.random.set_seed(42)
model2=tf.keras.Sequential()
model2.add(tf.keras.layers.Dense(1))
model2.compile(loss=tf.keras.losses.mae,optimizer=tf.keras.optimizers.Adam(),metrics=["mae"])
model2.fit(x,y,epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 9ms/step - loss: 35.0266 - mae: 35.0266
# Epoch 2/100
# 2/2 [==============================] - 0s 9ms/step - loss: 35.0253 - mae: 35.0253
# Epoch 3/100
# 2/2 [==============================] - 0s 0s/step - loss: 35.0243 - mae: 35.0243
# Epoch 4/100
# 2/2 [==============================] - 0s 0s/step - loss: 35.0231 - mae: 35.0231
# Epoch 5/100
# 2/2 [==============================] - 0s 8ms/step - loss: 35.0220 - mae: 35.0220
# Epoch 6/100
# 2/2 [==============================] - 0s 0s/step - loss: 35.0208 - mae: 35.0208
# Epoch 7/100
# 2/2 [==============================] - 0s 8ms/step - loss: 35.0197 - mae: 35.0197
# Epoch 8/100
# 2/2 [==============================] - 0s 1ms/step - loss: 35.0185 - mae: 35.0185
# Epoch 9/100
# 2/2 [==============================] - 0s 8ms/step - loss: 35.0175 - mae: 35.0175
# Epoch 10/100
# 2/2 [==============================] - 0s 10ms/step - loss: 35.0164 - mae: 35.0164
# Epoch 11/100
# ...

# %%
tf.random.set_seed(42)
model2=tf.keras.Sequential()
model2.add(tf.keras.layers.Dense(1))
model2.compile(loss=tf.keras.losses.mae,optimizer=tf.keras.optimizers.SGD(learning_rate=0.1),metrics=["mae"])
model2.fit(x,y,epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 0s/step - loss: 35.0457 - mae: 35.0457
# Epoch 2/100
# 2/2 [==============================] - 0s 0s/step - loss: 34.9825 - mae: 34.9825
# Epoch 3/100
# 2/2 [==============================] - 0s 8ms/step - loss: 34.9260 - mae: 34.9260
# Epoch 4/100
# 2/2 [==============================] - 0s 8ms/step - loss: 34.8671 - mae: 34.8671
# Epoch 5/100
# 2/2 [==============================] - 0s 8ms/step - loss: 34.8097 - mae: 34.8097
# Epoch 6/100
# 2/2 [==============================] - 0s 8ms/step - loss: 34.7509 - mae: 34.7509
# Epoch 7/100
# 2/2 [==============================] - 0s 9ms/step - loss: 34.6908 - mae: 34.6908
# Epoch 8/100
# 2/2 [==============================] - 0s 0s/step - loss: 34.6312 - mae: 34.6312
# Epoch 9/100
# 2/2 [==============================] - 0s 0s/step - loss: 34.5707 - mae: 34.5707
# Epoch 10/100
# 2/2 [==============================] - 0s 8ms/step - loss: 34.5153 - mae: 34.5153
# Epoch 11/100
# ...

# %%
tf.random.set_seed(42)
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(100))
# model.add(tf.keras.layers.Dense(50))
model.add(tf.keras.layers.Dense(1))
model.compile(loss=tf.keras.losses.mae,optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),metrics=["mae"])
model.fit(x,y,epochs=100) #tf.expand_dims(x,axis=1)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 0s/step - loss: 35.2819 - mae: 35.2819
# Epoch 2/100
# 2/2 [==============================] - 0s 9ms/step - loss: 34.9823 - mae: 34.9823
# Epoch 3/100
# 2/2 [==============================] - 0s 8ms/step - loss: 34.7104 - mae: 34.7104
# Epoch 4/100
# 2/2 [==============================] - 0s 1ms/step - loss: 34.3965 - mae: 34.3965
# Epoch 5/100
# 2/2 [==============================] - 0s 9ms/step - loss: 34.0845 - mae: 34.0845
# Epoch 6/100
# 2/2 [==============================] - 0s 16ms/step - loss: 33.7056 - mae: 33.7056
# Epoch 7/100
# 2/2 [==============================] - 0s 8ms/step - loss: 33.3470 - mae: 33.3470
# Epoch 8/100
# 2/2 [==============================] - 0s 8ms/step - loss: 32.9101 - mae: 32.9101
# Epoch 9/100
# 2/2 [==============================] - 0s 9ms/step - loss: 32.5022 - mae: 32.5022
# Epoch 10/100
# 2/2 [==============================] - 0s 16ms/step - loss: 32.0234 - mae: 32.0234
# Epoch 11/100
# ...

# %%
x_test=np.arange(-1,2,0.1)
y_pred=model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 136ms/step

# %%
plt.scatter(x,y)
plt.plot(x_test,y_pred,color='r')
plt.show()
